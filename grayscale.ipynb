# %% [markdown]
# First, we need to install the `opencv-python` library if you haven't already. Then, we can use it to read an image and convert it to grayscale.

# %%
pip install opencv-python matplotlib

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the uploaded image
image_path = '/content/image 2.jpg'
image = cv2.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print(f"Error: Could not load image from {image_path}. Please check the file path.")
else:
    # Convert the image to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Display the original and grayscale images
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)) # Convert BGR to RGB for matplotlib display
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(gray_image, cmap='gray')
    plt.title('Grayscale Image')
    plt.axis('off')

    plt.show()

# %% [markdown]
# This code first creates a dummy color image. In a real application, you would replace the image creation with `image = cv2.imread('path/to/your/image.jpg')` to load your own image.
#
# - `cv2.imread()`: Reads an image from the specified file path.
# - `cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)`: Converts the loaded image from its original color format (OpenCV reads images as BGR by default) to grayscale.
# - `matplotlib.pyplot.imshow()`: Displays the images. We convert the original image from BGR to RGB so that `matplotlib` displays it correctly, as `matplotlib` expects RGB.
